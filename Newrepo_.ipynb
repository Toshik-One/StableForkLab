# %%
#@title Запуск
# !apt-get install libgoogle-perftools-dev sox ffmpeg libcairo2 libcairo2-dev
# %pip install blendmodes accelerate basicsr fonts font-roboto gfpgan gradio==3.28.1 invisible-watermark numpy omegaconf opencv-contrib-python requests piexif Pillow pytorch-lightning==1.9.4 realesrgan scikit-image==0.19 timm==0.4.12 transformers==4.25.1 torch einops jsonmerge clean-fid resize-right torchdiffeq kornia lark inflection GitPython torchsde safetensors psutil rich manimlib pycairo svglib
# %cd /content/
# !git clone -q --branch main https://github.com/zetclansu/lite-kaggle
# %cd /content/lite-kaggle
# !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/lite-kaggle/modules/sd_models.py
# !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/lite-kaggle/startfk.py
# !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/lite-kaggle/modules/extras.py
# !cp /content/lite-kaggle/assets/blocks.py /usr/local/lib/python3.10/dist-packages/gradio/blocks.py
# !ln -s libtcmalloc.so.4 libtcmalloc.so
# !export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libtcmalloc.so
# !python launch.py --share --no-hashing --theme dark --api --ckpt-dir /content/models/ --disable-safe-unpickle --enable-insecure-extension-access --opt-sdp-attention --disable-console-progressbars --no-download-sd-model

# %%
#@title Модели
# !mkdir /content/lite-kaggle/models/Stable-diffusion
#!wget -O /content/lite-kaggle/models/Stable-diffusion/1Deliberate_v2.safetensors https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v2.safetensors
#!wget -O /content/lite-kaggle/models/Stable-diffusion/2Rev.safetensors https://huggingface.co/hanafuusen2001/ReVAnimated/resolve/main/revAnimated_v122.safetensors
#!wget -O /content/lite-kaggle/models/Stable-diffusion/Chhill.safetensors https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/ChilloutMix-ni-fp16.safetensors
#!wget -O /content/lite-kaggle/models/Stable-diffusion/Lyriel.safetensors https://civitai.com/api/download/models/72396?type=Model&format=SafeTensor&size=full&fp=fp16
#!wget -O /content/lite-kaggle/models/Stable-diffusion/Reliberate.safetensors https://civitai.com/api/download/models/84576?type=Model&format=SafeTensor&size=full&fp=fp16
#!wget -O /content/lite-kaggle/models/Stable-diffusion/EpicRealism.safetensors https://civitai.com/api/download/models/67990?type=Model&format=SafeTensor&size=pruned&fp=fp16

# %%
#@title VAE

# !wget -O /content/lite-kaggle/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors
#!wget -O /content/lite-kaggle/models/VAE/orangemix.vae.pt https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt

# %%
#@title Перезапуск
# %cd /content/lite-kaggle
# !python launch.py --ngrok ______ --theme dark --api --ckpt-dir /content/models/ --disable-safe-unpickle --enable-insecure-extension-access --opt-sdp-attention --disable-console-progressbars --no-download-sd-model
